# %%
import pandas
import matplotlib.pyplot as plt
import descartes
import geopandas as gpd
from shapely.geometry import Point,Polygon
# %matplotlib inline

# %%
map1 = gpd.read_file('500cities_tracts.geojson')
#fig,ax = plt.subplots(figsize=(15,15))
map1.plot(ax=ax)

# %%
map1.loc[4,'geometry']
