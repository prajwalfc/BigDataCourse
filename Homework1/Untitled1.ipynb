# %%
import pandas as pd

# %%
f =pd.read_csv('sale.csv')

# %%
f['Customer ID'].nunique()
# Out:
# 19

# %%
grouped_df = f.groupby('Product ID')['Customer ID']
grouped_df.nunique()
# Out:
# Product ID
# P02291    16
# P19498    17
# P32565    17
# P33162    18
# P39328    17
# P58225    17
# P61235    18
# P76615    18
# P82222    17
# P92449    14
# Name: Customer ID, dtype: int64

# %%
for key, item in grouped_df:
    print(key,grouped_df.get_group(key).c)
# Out:
# P02291      Customer ID Transaction ID        Date Product ID  Item Cost
# 1     1209690251         T37282  2014/03/25     P02291       6.99
# 6     1209690251         T13239  2013/03/09     P02291      19.99
# 9     1209690251         T13823  2016/11/01     P02291      16.99
# 50    2760114372         T24800  2016/04/17     P02291      13.99
# 63    2760114372         T37925  2016/01/12     P02291      13.99
# 64    2760114372         T06720  2014/05/10     P02291      11.99
# 65    3251575310         T33556  2013/00/01     P02291      18.99
# 79    3251575310         T00846  2017/02/06     P02291       7.99
# 89    3251575310         T18298  2014/10/07     P02291       6.99
# 97    3251575310         T44263  2018/07/24     P02291      14.99
# 112   3251575310         T06396  2018/10/17     P02291       7.99
# 134   3663438817         T33471  2014/00/21     P02291      19.99
# 137   3663438817         T42054  2014/04/14     P02291      17.99
# ...
