# %%
import csv
import datetime
import dateutil

# %%
def sales(filename):
    with open(filename, 'r') as fi:
        reader = csv.DictReader(fi)
        for row in reader:
            productName = (row['Product ID'])
            yield(productName)

# %%
for sale in sales('sale.csv'):
    print(sale)
# Out:
# P32565
# P02291
# P76615
# P61235
# P82222
# P33162
# P02291
# P33162
# P39328
# P02291
# P92449
# P58225
# P76615
# P61235
# P33162
# P32565
# P58225
# P32565
# P19498
# P19498
# P92449
# P58225
# P32565
# P58225
# P32565
# P82222
# P76615
# P19498
# P39328
# P32565
# P58225
# P58225
# P61235
# P58225
# P19498
# P58225
# P58225
# P92449
# P61235
# P92449
# P82222
# P58225
# P61235
# P58225
# P32565
# P58225
# P76615
# P92449
# P32565
# P82222
# P02291
# P58225
# P58225
# P82222
# P19498
# P76615
# P39328
# P58225
# P82222
# P76615
# P33162
# P33162
# P19498
# P02291
# P02291
# P02291
# P61235
# P33162
# P33162
# P32565
# P61235
# P32565
# P32565
# P76615
# P39328
# P19498
# P61235
# P39328
# P33162
# P02291
# P76615
# P76615
# P19498
# P33162
# P19498
# P61235
# P61235
# P58225
# P76615
# P02291
# P82222
# P61235
# P82222
# P61235
# P32565
# P39328
# P58225
# P02291
# P33162
# P76615
# P58225
# P19498
# P39328
# P58225
# P61235
# P92449
# P92449
# P61235
# P92449
# P92449
# P76615
# ...
