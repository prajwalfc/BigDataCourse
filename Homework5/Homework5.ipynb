# %%
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %%
import rtree
import fiona.crs
import geopandas as gpd

import csv
import pyproj
import shapely.geometry as geom
import pandas as pd
from shapely.geometry import Point
import geopandas as gpd

# %%
shapefile1 = 'neighborhoods.geojson'
shapefile2 = 'boroughs.geojson'

# %%
neighborhoods = gpd.read_file(shapefile1).to_crs(fiona.crs.from_epsg(2263))

# %%
neighborhoods.head(10)
# Out:
#         neighborhood    borough  \
# 0            Arverne     Queens
# 1      Broad Channel     Queens
# 2        City Island      Bronx
# 3           Edgemere     Queens
# 4       Ellis Island  Manhattan
# 5  Flatiron District  Manhattan
# 6    Gerritsen Beach   Brooklyn
# 7           Sea Gate   Brooklyn
# 8   Theater District  Manhattan
# 9        Throgs Neck      Bronx
#
#                                             geometry
# 0  (POLYGON ((1042695.412681766 157932.5909777609...
# 1  (POLYGON ((1041567.549112549 166236.1995676621...
# 2  (POLYGON ((1044339.234277936 246814.3387770021...
# 3  (POLYGON ((1048643.510334172 157165.0353089103...
# 4  (POLYGON ((972697.5892621228 193015.8087967168...
# 5  (POLYGON ((988855.2701673006 209379.9600719535...
# 6  (POLYGON ((1002290.931614938 158511.011148033,...
# 7  (POLYGON ((983172.240287415 151181.7700830512,...
# 8  (POLYGON ((988393.9578039492 213817.0774394181...
# 9  (POLYGON ((1032350.968268547 234897.0683896745...

# %%
boroughs = gpd.read_file(shapefile2).to_crs(fiona.crs.from_epsg(2263))

# %%
boroughs.head()
# Out:
#         boroname                                           geometry
# 0  Staten Island  (POLYGON ((970217.0401832734 145643.3197584194...
# 1         Queens  (POLYGON ((1029606.004483169 156073.9244595101...
# 2       Brooklyn  (POLYGON ((1021176.616410234 151374.8056603043...
# 3      Manhattan  (POLYGON ((981219.17021961 188655.1436204575, ...
# 4          Bronx  (POLYGON ((1012821.759526813 229228.102345575,...

# %%
# taxi = sc.textFile('yellow.csv')
# taxi.first()
# Out:
# 'tpep_pickup_datetime,tpep_dropoff_datetime,pickup_latitude,pickup_longitude,dropoff_latitude,dropoff_longitude'

# %%
# df = spark.read.format("csv").option("header", "true").load("yellow.csv")

# %%
# df.show()

# %%
# boroughs.crs

# %%
# neighborhoods.crs

# %%
# from pyspark.sql.functions import udf
# mergeCols = udf(lambda lat, long: lat +','+ long)

# %%
# from pyspark.sql.functions import udf
# crs = {'init': 'epsg:2263'}
# def getPointImpl(lat,lon):
#     import pyproj
#     from shapely.geometry import Point
#     proj = pyproj.Proj(init = 'epsg:2263',preserver_units = True)
#     point1 = proj(lat,lon)
#     point = Point(point1[0],point1[1])
#     print(point)
#     return point
# def mergeCols(lat,lon):
#     return lat+','+lon
# getPoint = udf(getPointImpl)

# %%
# from pyspark.sql.functions import concat_ws
# df.withColumn("geometry", getPoint(col("dropoff_latitude"), col("dropoff_longitude"))).show(1,False)
# #df.select(concat_ws(',',df.dropoff_latitude, df.dropoff_longitude).alias('s')).collect()

# %%
# df['Coordinates'] = list(zip(df.dropoff_longitude, df.dropoff_latitude))

# %%
df = pd.read_csv('yellow.csv')

# %%
projection = lambda point: proj(point.x,point.y)

# %%
df['geometry'] = list(zip(df.dropoff_longitude, df.dropoff_latitude))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1011         try:
# -> 1012             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1013         except TypeError:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ...

# %%
df['geometry'] = df['geometry'].apply(Point)

# %%
gdf = gpd.GeoDataFrame(df, geometry='geometry')

# %%
gdf['geometry'] = df['geometry'].apply(projection)

# %%
gdf
# Out:
#          tpep_pickup_datetime  tpep_dropoff_datetime  pickup_latitude  \
# 0       2015-02-01 00:00:00.0  2015-02-01 00:10:10.0        40.775486
# 1       2015-02-01 00:00:00.0  2015-02-01 00:03:36.0        40.728249
# 2       2015-02-01 00:00:00.0  2015-02-01 00:10:32.0        40.731014
# 3       2015-02-01 00:00:00.0  2015-02-01 00:19:42.0        40.721115
# 4       2015-02-01 00:00:00.0  2015-02-01 00:03:11.0        40.756073
# 5       2015-02-01 00:00:00.0  2015-02-01 00:00:00.0        40.730934
# 6       2015-02-01 00:00:00.0  2015-02-01 00:00:00.0        40.766895
# 7       2015-02-01 00:00:00.0  2015-02-01 20:29:47.0        40.766098
# 8       2015-02-01 00:00:00.0  2015-02-01 00:17:07.0        40.778389
# 9       2015-02-01 00:00:00.0  2015-02-01 00:06:24.0        40.783718
# 10      2015-02-01 00:00:00.0  2015-02-01 00:11:56.0        40.737053
# 11      2015-02-01 00:00:01.0  2015-02-01 00:13:44.0        40.776417
# ...
